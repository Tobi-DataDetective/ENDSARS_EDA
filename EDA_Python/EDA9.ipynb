# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Bivariate Analysis

# %%
df = pd.read_csv('engineered_data.csv')
df['Year']= df['Year'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641043 entries, 0 to 641042
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   tweets        641043 non-null  object
#  1   Month         641043 non-null  object
#  2   Day           641043 non-null  int64
#  3   Year          641043 non-null  object
#  4   full_date     641043 non-null  object
#  5   dayofdate     641043 non-null  object
#  6   subjectivity  641043 non-null  float64
#  7   polarity      641043 non-null  float64
#  8   Sentiment     641043 non-null  object
#  9   review_len    641043 non-null  int64
#  10  word_len      641043 non-null  int64
#  11  avg_word_len  641043 non-null  float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 58.7+ MB

# %%
sns.pairplot(df, hue='Sentiment')

# %%
df.head()
# Out:
#                                               tweets    Month  Day  Year  \
# 0           I actually thought we'd be made of more   January   27  2017
# 1    You mean  there are more colours! What burple?   January   27  2017
# 2  Just the one new follower today found welcome ...  January   27  2017
# 3                                              Woah   January   26  2017
# 4  Conversation\nVerbal elation\nStimulation\nSit...  January   26  2017
#
#     full_date dayofdate  subjectivity  polarity Sentiment  review_len  \
# 0  01/27/2017    Friday      0.300000  0.250000  Positive          40
# 1  01/27/2017    Friday      0.593750  0.156250  Positive          47
# 2  01/27/2017    Friday      0.677273  0.468182  Positive          57
# 3  01/26/2017  Thursday      0.000000  0.000000   Neutral           5
# 4  01/26/2017  Thursday      0.000000  0.000000   Neutral          51
#
#    word_len  avg_word_len
# 0         8      3.999995
# 1         8      4.749994
# ...

# %%
### Creatign a Month Year Column
df['Month_Year'] = df['Month'] + df['Year']
df.head()
# Out:
#                                               tweets    Month  Day  Year  \
# 0           I actually thought we'd be made of more   January   27  2017
# 1    You mean  there are more colours! What burple?   January   27  2017
# 2  Just the one new follower today found welcome ...  January   27  2017
# 3                                              Woah   January   26  2017
# 4  Conversation\nVerbal elation\nStimulation\nSit...  January   26  2017
#
#     full_date dayofdate  subjectivity  polarity Sentiment  review_len  \
# 0  01/27/2017    Friday      0.300000  0.250000  Positive          40
# 1  01/27/2017    Friday      0.593750  0.156250  Positive          47
# 2  01/27/2017    Friday      0.677273  0.468182  Positive          57
# 3  01/26/2017  Thursday      0.000000  0.000000   Neutral           5
# 4  01/26/2017  Thursday      0.000000  0.000000   Neutral          51
#
#    word_len  avg_word_len   Month_Year
# 0         8      3.999995  January2017
# ...

# %%
df.to_csv('engineered_data2.csv', index=False)

# %%
df = pd.read_csv('engineered_data.csv')

# %%
sns.catplot(x='Year', y='polarity', data=df, kind='box')

# %%
sns.catplot(x='Month', y='polarity', data=df, kind='box')

# %%
sns.catplot(x='Year', y='review_len', data=df, kind='box')

# %%
sns.catplot(x='Month', y='review_len', data=df, kind='box')
