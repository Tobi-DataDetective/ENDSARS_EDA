# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools

# %%
Jan2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-01-01" until:2017-01-28').get_items(), 50000))

# %%
len(Jan2017)
# Out:
# 52

# %%
Feb2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-02-01" until:2017-02-28').get_items(), 50000))

# %%
len(Feb2017)
# Out:
# 0

# %% [markdown]
# ### 2017

# %%
Jan2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-01-01" until:2017-01-28').get_items(), 50000))

Feb2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-02-01" until:2017-02-28').get_items(), 50000))

Mar2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-03-01" until:2017-03-28').get_items(), 50000))

Apr2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-04-01" until:2017-04-28').get_items(), 50000))

May2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-05-01" until:2017-05-28').get_items(), 50000))

Jun2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-06-01" until:2017-06-28').get_items(), 50000))

Jul2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-07-01" until:2017-07-28').get_items(), 50000))

Aug2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-08-01" until:2017-08-28').get_items(), 50000))

Sep2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-09-01" until:2017-09-28').get_items(), 50000))

Oct2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-10-01" until:2017-10-28').get_items(), 50000))

Nov2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-11-01" until:2017-11-28').get_items(), 50000))

Dec2017 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2017-12-01" until:2017-12-28').get_items(), 50000))

# %%
endsar_2017 = Jan2017.append([Feb2017, Mar2017, Apr2017, May2017, Jun2017, Jul2017, Aug2017, Sep2017, Oct2017, Nov2017,
                             Dec2017])

endsar_2017.to_csv('endsars_2017.csv')
len(endsar_2017)

# %%
import_2017_data = pd.read_csv('endsars_2017.csv')
import_2017_data.head()

#len(endsar_2017)
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://twitter.com/endsars___/status/82488947...
# 1           1  https://twitter.com/endsars___/status/82488922...
# 2           2  https://twitter.com/Miracle_C00L/status/824820...
# 3           3  https://twitter.com/endsars___/status/82470376...
# 4           4  https://twitter.com/endsars___/status/82470204...
#
#                         date  \
# 0  2017-01-27 07:59:10+00:00
# 1  2017-01-27 07:58:11+00:00
# 2  2017-01-27 03:26:43+00:00
# 3  2017-01-26 19:41:14+00:00
# 4  2017-01-26 19:34:25+00:00
#
#                                              content  \
# 0  I actually thought we'd be made of more https:...
# 1  You mean  there are more colours! What burple?...
# 2  Just the one new follower today found welcome ...
# 3                       Woah https://t.co/8AZ4I5I1Cl
# 4  Conversation\nVerbal elation\nStimulation\nSit...
#
# ...

# %% [markdown]
# ### 2018

# %%
Jan2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-01-01" until:2018-01-28').get_items(), 50000))

Feb2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-02-01" until:2018-02-28').get_items(), 50000))

Mar2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-03-01" until:2018-03-28').get_items(), 50000))

Apr2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-04-01" until:2018-04-28').get_items(), 50000))

May2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-05-01" until:2018-05-28').get_items(), 50000))

Jun2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-06-01" until:2018-06-28').get_items(), 50000))

Jul2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-07-01" until:2018-07-28').get_items(), 50000))

Aug2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-08-01" until:2018-08-28').get_items(), 50000))

Sep2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-09-01" until:2018-09-28').get_items(), 50000))

Oct2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-10-01" until:2018-10-28').get_items(), 50000))

Nov2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-11-01" until:2018-11-28').get_items(), 50000))

Dec2018 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2018-12-01" until:2018-12-28').get_items(), 50000))



endsar_2018 = Jan2018.append([Feb2018, Mar2018, Apr2018, May2018, Jun2018, Jul2018, Aug2018, Sep2018, Oct2018, Nov2018,
                             Dec2018])

endsar_2018.to_csv('endsars_2018.csv')
len(endsar_2018)
# Out:
# 67900

# %% [markdown]
# ### 2019

# %%
Jan2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-01-01" until:2019-01-28').get_items(), 50000))

Feb2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-02-01" until:2019-02-28').get_items(), 50000))

Mar2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-03-01" until:2019-03-28').get_items(), 50000))

Apr2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-04-01" until:2019-04-28').get_items(), 50000))

May2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-05-01" until:2019-05-28').get_items(), 50000))

Jun2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-06-01" until:2019-06-28').get_items(), 50000))

Jul2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-07-01" until:2019-07-28').get_items(), 50000))

Aug2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-08-01" until:2019-08-28').get_items(), 50000))

Sep2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-09-01" until:2019-09-28').get_items(), 50000))

Oct2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-10-01" until:2019-10-28').get_items(), 50000))

Nov2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-11-01" until:2019-11-28').get_items(), 50000))

Dec2019 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2019-12-01" until:2019-12-28').get_items(), 50000))


endsar_2019 = Jan2019.append([Feb2019, Mar2019, Apr2019, May2019, Jun2019, Jul2019, Aug2019, Sep2019, Oct2019, Nov2019,
                             Dec2019])

endsar_2019.to_csv('endsars_2019.csv')
len(endsar_2019)

# %%
endsars_2019 = pd.read_csv('endsars_2019.csv')
endsars_2019.tail()
# Out:
#        Unnamed: 0                                                url  \
# 47963        3234  https://twitter.com/SninCode/status/1201144930...
# 47964        3235  https://twitter.com/justifiedkwame/status/1201...
# 47965        3236  https://twitter.com/Officialrerome1/status/120...
# 47966        3237  https://twitter.com/Officialrerome1/status/120...
# 47967        3238  https://twitter.com/omuhiinda1/status/12010190...
#
#                             date  \
# 47963  2019-12-01 14:24:02+00:00
# 47964  2019-12-01 14:08:57+00:00
# 47965  2019-12-01 14:05:25+00:00
# 47966  2019-12-01 12:55:24+00:00
# 47967  2019-12-01 06:03:51+00:00
#
#                                                  content  \
# 47963  @OAUSecurityDep @insideOAU Major security thre...
# 47964  @begundedaniel @segalink Receipt or no receipt...
# 47965  https://t.co/f96gC9wkHL\n\nHow ladies reacted ...
# 47966  https://t.co/HhI3Qq9O7e\n\nWhat Burna Boy and ...
# ...

# %% [markdown]
# ### 2020

# %%
Jan2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-01-01" until:2020-01-28').get_items(), 50000))

Feb2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-02-01" until:2020-02-28').get_items(), 50000))

Mar2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-03-01" until:2020-03-28').get_items(), 50000))

Apr2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-04-01" until:2020-04-28').get_items(), 50000))

May2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-05-01" until:2020-05-28').get_items(), 50000))

Jun2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-06-01" until:2020-06-28').get_items(), 50000))

Jul2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-07-01" until:2020-07-28').get_items(), 50000))

Aug2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-08-01" until:2020-08-28').get_items(), 50000))

Sep2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-09-01" until:2020-09-28').get_items(), 50000))

Oct2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-10-01" until:2020-10-28').get_items(), 50000))

Nov2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-11-01" until:2020-11-28').get_items(), 50000))

Dec2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2020-12-01" until:2020-12-28').get_items(), 50000))



endsar_2020 = Jan2020.append([Feb2020, Mar2020, Apr2020, May2020, Jun2020, Jul2020, Aug2020, Sep2020, Oct2020, Nov2020,
                             Dec2020])

endsar_2020.to_csv('endsars_2020.csv')
len(endsar_2020)
# Out:
# Error retrieving https://twitter.com/search?f=live&lang=en&q=ENDSARS+since%3A%222020-01-01%22+until%3A2020-01-28&src=spelling_expansion_revert_click: ConnectTimeout(MaxRetryError("HTTPSConnectionPool(host='twitter.com', port=443): Max retries exceeded with url: /search?f=live&lang=en&q=ENDSARS+since%3A%222020-01-01%22+until%3A2020-01-28&src=spelling_expansion_revert_click (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000204B490E040>, 'Connection to twitter.com timed out. (connect timeout=10)'))"))
# 4 requests to https://twitter.com/search?f=live&lang=en&q=ENDSARS+since%3A%222020-01-01%22+until%3A2020-01-28&src=spelling_expansion_revert_click failed, giving up.
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-9-b489b003c20c> in <module>
# ----> 1 Jan2020 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
# ...

# %% [markdown]
# ### 2021

# %%
Jan2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-01-01" until:2021-01-28').get_items(), 50000))

Feb2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-02-01" until:2021-02-28').get_items(), 50000))

Mar2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-03-01" until:2021-03-28').get_items(), 50000))

Apr2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-04-01" until:2021-04-28').get_items(), 50000))

May2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-05-01" until:2021-05-28').get_items(), 50000))

Jun2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-06-01" until:2021-06-28').get_items(), 50000))

Jul2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-07-01" until:2021-07-28').get_items(), 50000))

Aug2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-08-01" until:2021-08-28').get_items(), 50000))

Sep2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-09-01" until:2021-09-28').get_items(), 50000))

Oct2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'ENDSARS since:"2021-10-01" until:2021-10-24').get_items(), 50000))

# Nov2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
#     'ENDSARS since:"2021-11-01" until:2021-11-28').get_items(), 50000))

# Dec2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
#     'ENDSARS since:"2021-12-01" until:2021-12-28').get_items(), 50000))



endsar_2021 = Jan2021.append([Feb2021, Mar2021, Apr2021, May2021, Jun2021, Jul2021, Aug2021, Sep2021, Oct2021])

endsar_2021.to_csv('endsars_2021.csv')
len(endsar_2021)
# Out:
# Error retrieving https://twitter.com/search?f=live&lang=en&q=ENDSARS+since%3A%222021-01-01%22+until%3A2021-01-28&src=spelling_expansion_revert_click: ConnectTimeout(MaxRetryError("HTTPSConnectionPool(host='twitter.com', port=443): Max retries exceeded with url: /search?f=live&lang=en&q=ENDSARS+since%3A%222021-01-01%22+until%3A2021-01-28&src=spelling_expansion_revert_click (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000204B2875040>, 'Connection to twitter.com timed out. (connect timeout=10)'))"))
# 4 requests to https://twitter.com/search?f=live&lang=en&q=ENDSARS+since%3A%222021-01-01%22+until%3A2021-01-28&src=spelling_expansion_revert_click failed, giving up.
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-10-cbb79716f6c9> in <module>
# ----> 1 Jan2021 = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
# ...
